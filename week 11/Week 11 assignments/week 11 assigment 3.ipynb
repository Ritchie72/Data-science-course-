# %% [markdown]
# ## Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %% [markdown]
# Estimation statistics involve inferring population parameters based on sample data. A point estimate provides a single value as an estimate (e.g., sample mean), while an interval estimate gives a range (e.g., confidence interval) within which the parameter is likely to fall.

# %% [markdown]
# ## Q2. Write a Python function to estimate the population mean using a sample mean and standard deviation.

# %%
def estimate_population_mean(sample_mean, sample_std_dev, sample_size):
    return sample_mean

# %% [markdown]
# ## Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %% [markdown]
# Hypothesis testing is a statistical method to evaluate a claim or hypothesis about a population parameter using sample data. It is essential for making data-driven decisions, as it helps determine if observed results are statistically significant or likely due to random chance.

# %% [markdown]
# ## Q4. Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# The hypothesis could be stated as follows:
# 1] Null Hypothesis (H0): The average weight of male college students is equal to or less than the average weight of female college students.
# 2] Alternative Hypothesis (H1): The average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# ## Q5. Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.

# %%
import scipy.stats as stats

def hypothesis_test_means(sample1, sample2, alpha=0.05):
    mean1, mean2 = sample1.mean(), sample2.mean()
    std_dev1, std_dev2 = sample1.std(ddof=1), sample2.std(ddof=1)
    n1, n2 = len(sample1), len(sample2)
    t_statistic, p_value = stats.ttest_ind(sample1, sample2, equal_var=False)
    if p_value < alpha:
        result = "Reject the null hypothesis (significant difference between the means)."
    else:
        result = "Fail to reject the null hypothesis (no significant difference between the means)."
    
    return t_statistic, p_value, result

# %% [markdown]
# ## Q6: What is a null and alternative hypothesis? Give some examples.

# %% [markdown]
# The null hypothesis (H0) is a statement that assumes no effect or no difference, while the alternative hypothesis (H1) proposes that there is an effect or a difference. Examples include testing whether a new drug is more effective than a placebo (H0: no difference, H1: the drug is more effective) or if the mean income differs between two cities (H0: means are equal, H1: means are different).

# %% [markdown]
# ## Q7: Write down the steps involved in hypothesis testing

# %% [markdown]
# 1] State the hypothesis.
# 2] Set the significance value.
# 3] Choose the appropriate test.
# 4] Calculate the test statistic and p-value.
# 5] Make a decision.
# 6] Interpret the result.

# %% [markdown]
# ## Q8. Define p-value and explain its significance in hypothesis testing.

# %% [markdown]
# The p-value is the probability of observing results as extreme as those in your sample, assuming the null hypothesis is true. In hypothesis testing, a low p-value (typically ≤ 0.05) suggests strong evidence against the null hypothesis, leading to its rejection in favor of the alternative hypothesis.

# %% [markdown]
# ## Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

df = 10
x = np.linspace(-4, 4, 1000)
t_pdf = stats.t.pdf(x, df)
plt.plot(x, t_pdf, label=f"t-distribution (df={df})", color='blue')
plt.title("Student's t-Distribution (df=10)")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.

# %%
import numpy as np
import scipy.stats as stats

def two_sample_t_test(sample1, sample2, alpha=0.05):
    mean1 = np.mean(sample1)
    mean2 = np.mean(sample2)
    std_dev1 = np.std(sample1, ddof=1)  
    std_dev2 = np.std(sample2, ddof=1)
    n1 = len(sample1)
    n2 = len(sample2)
    pooled_std_dev = np.sqrt(((n1 - 1) * std_dev1**2 + (n2 - 1) * std_dev2**2) / (n1 + n2 - 2))
    t_statistic = (mean1 - mean2) / (pooled_std_dev * np.sqrt(1/n1 + 1/n2))
    df = n1 + n2 - 2

    p_value = 2 * (1 - stats.t.cdf(np.abs(t_statistic), df)) 


    if p_value < alpha:
        result = "Reject the null hypothesis (significant difference between the means)."
    else:
        result = "Fail to reject the null hypothesis (no significant difference between the means)."

    return t_statistic, p_value, result

# %% [markdown]
# ## Q11: What is Student’s t distribution? When to use the t-Distribution.

# %% [markdown]
# Student’s t-distribution is a probability distribution used for estimating population parameters when the sample size is small and the population standard deviation is unknown. It is typically used in hypothesis testing and confidence interval estimation for small samples (typically less than 30) where the data is assumed to be normally distributed.

# %% [markdown]
# ## Q12: What is t-statistic? State the formula for t-statistic.

# %% [markdown]
# The t-statistic is a standardized value that measures the difference between the sample mean and the population mean relative to the variability of the sample, used in t-tests. The formula for the t-statistic is given by:
#                                     t = (x - u)/s/root(n)

# %% [markdown]
# ## Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50. Estimate the population mean revenue with a 95% confidence interval.

# %%
import scipy.stats as stats
import numpy as np
sample_mean = 500  
sample_std_dev = 50 
n = 50  
confidence_level = 0.95  
sem = sample_std_dev / np.sqrt(n)
t_critical = stats.t.ppf((1 + confidence_level) / 2, df=n-1)
margin_of_error = t_critical * sem
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)
confidence_interval
# Out:
# (485.79015722521353, 514.2098427747865)

# %% [markdown]
# ## Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %%
hypothesized_mean = 10
sample_mean = 8  
sample_std_dev = 3  
n = 100  
alpha = 0.05  
sem = sample_std_dev / np.sqrt(n)
t_statistic = (sample_mean - hypothesized_mean) / sem
df = n - 1
t_critical = stats.t.ppf(1 - alpha, df)
reject_null = t_statistic < -t_critical
t_statistic, t_critical, reject_null
# Out:
# (-6.666666666666667, 1.6603911559963895, True)

# %% [markdown]
# ## Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.

# %%
population_mean = 5  
sample_mean = 4.8  
population_std_dev = 0.5
n = 25  
alpha = 0.01  
sem = population_std_dev / np.sqrt(n)
z_statistic = (sample_mean - population_mean) / sem
z_critical = stats.norm.ppf(1 - alpha)
reject_null = z_statistic < -z_critical
z_statistic, z_critical, reject_null
# Out:
# (-2.0000000000000018, 2.3263478740408408, False)

# %% [markdown]
# ## Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 = 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two groups are equal with a significance level of 0.01.

# %%
mean1 = 80 
std_dev1 = 10  
n1 = 30  
mean2 = 75 
std_dev2 = 8 
n2 = 40  

alpha = 0.01  
se_diff = np.sqrt((std_dev1**2 / n1) + (std_dev2**2 / n2))
z_statistic = (mean1 - mean2) / se_diff
z_critical = stats.norm.ppf(1 - alpha / 2)
reject_null = abs(z_statistic) > z_critical
z_statistic, z_critical, reject_null
# Out:
# (2.2511258444537408, 2.5758293035489004, False)

# %% [markdown]
# ## Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %%
sample_mean = 4  
sample_std_dev = 1.5  
n = 50  
confidence_level = 0.99 
sem = sample_std_dev / np.sqrt(n)
t_critical = stats.t.ppf((1 + confidence_level) / 2, df=n-1)
margin_of_error = t_critical * sem
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)
confidence_interval
# Out:
# (3.4314963358572577, 4.568503664142742)
